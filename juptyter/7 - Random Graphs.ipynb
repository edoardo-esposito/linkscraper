# %%
import pandas as pd
import numpy as np
import json
import nltk
import re
import csv
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from datetime import datetime
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
import datetime
import pickle

# %%
input_filename = 'temp/db'
articoli = pd.read_csv(input_filename, sep=";")
del(articoli["Unnamed: 0"])

# %%
articoli.head()
# Out:
#                                  ID  \
# 0  2b62c9c3c72cdf9219cde304910ba6f1
# 1  fc904ef82779aaa9114df97e8284102a
# 2  39c4b22ec26c42bb7d362fd29640af33
# 3  9ebbc6b5ee19c55075ae8d971a9efeff
# 4  f86f243a8dcef8cc2e88c5e76cd0fdee
#
#                                               Titolo        Data  \
# 0          Flexible Thin-film Fast Charge Battery...  2018-12-05
# 1   Connecting Start-ups to Technical Experts via...  2019-02-01
# 2  Nuts & Bolts — Taking the Sting Out of Medical...  2019-04-10
# 3        Singapore-Finland Collaboration in Smart...  2019-04-11
# 4     Learning about Technology Transfer in IPI's...  2019-04-25
#
#                                                Testo  \
# 0  With the rise of Internet of Things and wearab...
# 1  Start ups grapple with numerous challenges and...
# 2  Healthcare Made Non Invasive New technology an...
# 3  The Finnish Smart Building Technology Matchmak...
# 4  IPI organised its first Technology Commerciali...
#
#                                                Trend  \
# 0  Transition to Renewable and New Sources of Energy
# 1                                    Open Innovation
# 2                                        Health Tech
# 3                Rapid Urbanization and Smart Cities
# 4                                    Open Innovation
#
#                                                  Txt  Anno  Mese  Day  Week  \
# 0  flexible thin film fast charge battery rise in...  2018    12    5    49
# 1  connecting start ups technical experts via sta...  2019     2    1     5
# 2  nuts bolts taking sting medical healthcare mad...  2019     4   10    15
# 3  singapore finland collaboration smart finnish ...  2019     4   11    15
# 4  learning technology transfer ipis ipi organise...  2019     4   25    17
#
#                                             Keywords  \
# 0  battery, flexible, thin film, ipi, thin, film,...
# 1  start ups, ups, start, innovation, ipi, produc...
# 2  prostate, prostate cancer, invasive, fertility...
# 3  singapore, collaboration, smart, programme, bu...
# 4  workshop, technology transfer, commercialisati...
#
#                                                Words  \
# 0  ['battery', 'internet things', 'military', 'te...
# 1  ['development', 'innovation', 'product develop...
# 2                              ['cancer', 'medical']
# 3  ['innovative', 'innovative solutions', 'roboti...
# 4            ['intellectual property', 'technology']
#
#                                         ComputedTags Company  \
# 0  Tag: Tech, Tech: Wearables, Tag: Military, Tec...     NaN
# 1                  Tag: Innovation, Tag: Development     NaN
# 2          Vertical: Health & Medicine, Tag: Disease     NaN
# 3  Tech: Robotics, Tag: Innovation, Tag: Tech, Lo...     NaN
# 4              Tag: Intellectual Property, Tag: Tech     NaN
#
#                            Tag   Location                       Tech People  \
# 0               Tech, Military        NaN  Wearables, IoT, Batteries    NaN
# 1      Innovation, Development        NaN                        NaN    NaN
# 2                      Disease        NaN                        NaN    NaN
# 3             Innovation, Tech  Singapore                   Robotics    NaN
# 4  Intellectual Property, Tech        NaN                        NaN    NaN
#
#             Vertical     Application
# 0                NaN  Energy Storage
# 1                NaN             NaN
# 2  Health & Medicine             NaN
# 3                NaN             NaN
# 4                NaN             NaN
