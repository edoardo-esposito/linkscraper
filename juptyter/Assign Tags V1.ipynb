# %%
import pandas as pd
import numpy as np
import json
import nltk
import re
import csv
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from datetime import datetime
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# %%
meta = pd.read_csv('Articoli Taggati v8.csv', sep=";", skipinitialspace = True, quotechar='"')
meta = meta.replace(np.nan, '', regex=True)
del(meta['Unnamed: 0'])
del(meta['Txt'])

# %%
meta.head()
# Out:
#                                  ID  \
# 0  c812e0a3418d624ae60df3ec9e19d184
# 1  0e2ef6bd7619374e0531d1551ab2141e
# 2  8602d8791a1754506303dcfd9a7b79e3
# 3  2157ac6d12e063b6a38c5c0491e0b322
# 4  3c06ef110a3efad83733ad876816e16f
#
#                                               Titolo        Data  \
# 0                       pandemic drone spot infected  03/04/2020
# 1                     census data anonymous expected  07/04/2020
# 2  common pandemic scams highlighted domain name ...  11/05/2020
# 3   questions rapidly unfolding future smart fabrics  11/05/2020
# 4                 things ceo expect remote work life  17/05/2020
#
#                                       Trend  Anno  Mese  Day  Week  \
# 0  Robotics and Human/Machine Hybridization  2020     4    3    14
# 1            Privacy and Security by design  2020     4    7    15
# 2     Cyber Defense and Fight against Fakes  2020     5   11    20
# 3                  Workforce Transformation  2020     5   11    20
# 4                  Workforce Transformation  2020     5   17    20
#
#                                             Keywords  \
# 0  drone,detect,respiratory,infected,heart,pandem...
# 1  census,cookies,ad,tracking,adobe,file,party,we...
# 2  scams,fake,information,domain names,sites,doma...
# 3  unfolding,analyze,signs,monitor,vital,question...
# 4  productivity,im,bump,remote,meetings,working,z...
#
#                                   Tags_x  ... Application_x Location_x  \
# 0                           Tech: Drones  ...
# 1  Company: Adobe, Vertical: Advertising  ...
# 2                                         ...
# 3                            Tag: Future  ...
# 4                                         ...
#
#     Tag_x                                 Tags_y  Tech_y Company_y  \
# 0                                   Tech: Drones  Drones
# 1          Company: Adobe, Vertical: Advertising             Adobe
# 2
# 3  Future                            Tag: Future
# 4
#
#     Vertical_y Application_y Location_y   Tag_y
# 0
# 1  Advertising
# 2
# 3                                        Future
# 4
#
# [5 rows x 23 columns]

# %%
print ("Numero: %d" % len(meta['ID']))
# Out:
# Numero: 439

# %%
meta['Keywords'][1].split(',')
# Out:
# ['census',
#  'cookies',
#  'ad',
#  'tracking',
#  'adobe',
#  'file',
#  'party',
#  'website',
#  'ads',
#  'websites',
#  'third',
#  'third party',
#  'browser',
#  'com',
#  'privacy',
#  'page',
#  'networks',
#  'anonymous',
#  'representation',
#  'configuration',
#  'net',
#  'performance',
#  'visitors',
#  'data',
#  'ensure']

# %%
tags = pd.read_excel("Keywords to Tags V2.xlsx", encoding="utf8", error_bad_lines=False)
tags = tags.replace(np.nan, '', regex=True)
del(tags['Tag 1'])
del(tags['Tag 2'])
del(tags['Tag 3'])

# %%
tags.head()
# Out:
#           Words                                           Tags
# 0  aarogya setu  Tech: Mobile app|Application: contact tracing
# 1      academic                           Vertical: University
# 2     acquiring                                  Vertical: M&A
# 3            ad                          Vertical: Advertising
# 4   ad networks                          Vertical: Advertising

# %%
articoli = meta[['ID','Keywords']]

# %%
articoli.head()
# Out:
#                                  ID  \
# 0  c812e0a3418d624ae60df3ec9e19d184
# 1  0e2ef6bd7619374e0531d1551ab2141e
# 2  8602d8791a1754506303dcfd9a7b79e3
# 3  2157ac6d12e063b6a38c5c0491e0b322
# 4  3c06ef110a3efad83733ad876816e16f
#
#                                             Keywords
# 0  drone,detect,respiratory,infected,heart,pandem...
# 1  census,cookies,ad,tracking,adobe,file,party,we...
# 2  scams,fake,information,domain names,sites,doma...
# 3  unfolding,analyze,signs,monitor,vital,question...
# 4  productivity,im,bump,remote,meetings,working,z...

# %%
words = pd.concat([pd.Series(row['ID'], row['Keywords'].split(',')) 
           for _, row in articoli.iterrows()]).reset_index().rename(columns={"index": "Words", 0: "ID"})

# %%
words.head()
# Out:
#          Words                                ID
# 0        drone  c812e0a3418d624ae60df3ec9e19d184
# 1       detect  c812e0a3418d624ae60df3ec9e19d184
# 2  respiratory  c812e0a3418d624ae60df3ec9e19d184
# 3     infected  c812e0a3418d624ae60df3ec9e19d184
# 4        heart  c812e0a3418d624ae60df3ec9e19d184

# %%
res = tags.merge(words, on="Words", how='left')

# %%
res.head()
# Out:
#           Words                                           Tags  \
# 0  aarogya setu  Tech: Mobile app|Application: contact tracing
# 1      academic                           Vertical: University
# 2      academic                           Vertical: University
# 3     acquiring                                  Vertical: M&A
# 4     acquiring                                  Vertical: M&A
#
#                                  ID
# 0                               NaN
# 1  cf4a502cbc3be4bf184002d5db67ac81
# 2  c3867e2ca29ffade71f104301bf2a743
# 3  cad8439052150cc0cb779feaa0a2a50d
# 4  9d3d71da7640282e1e4a788a1dd361a3

# %%
res = res.groupby('ID').agg(lambda x: x.tolist())

# %%
res.head()
# Out:
#                                                                               Words  \
# ID
# 0041230019f3679d60b2900af083d41d                                         [european]
# 010ce8162408ed1d3d3dab7b9a852736                                       [automotive]
# 024e39e4c912e043aceb022b442f8a6e  [amazon, bay area, seattle, silicon valley, tech]
# 02783899e72f373f5fa8b56cb84b7d1a          [agencies, health, hospital, rpa, uipath]
# 02e960a1e7d6d7fd4b4bae904343bdf1             [agency, batteries, game, kickstarter]
#
#                                                                               Tags
# ID
# 0041230019f3679d60b2900af083d41d                                [Location: Europe]
# 010ce8162408ed1d3d3dab7b9a852736                            [Vertical: Automotive]
# 024e39e4c912e043aceb022b442f8a6e  [Company: Amazon, Location: San Francisco, , , ]
# 02783899e72f373f5fa8b56cb84b7d1a                   [Vertical: Advertising, , , , ]
# 02e960a1e7d6d7fd4b4bae904343bdf1      [Vertical: Advertising, Tech: Batteries, , ]

# %%
df = meta.merge(res, on="ID", how='left')

# %%
df.head()
# Out:
#                                  ID  \
# 0  c812e0a3418d624ae60df3ec9e19d184
# 1  0e2ef6bd7619374e0531d1551ab2141e
# 2  8602d8791a1754506303dcfd9a7b79e3
# 3  2157ac6d12e063b6a38c5c0491e0b322
# 4  3c06ef110a3efad83733ad876816e16f
#
#                                               Titolo        Data  \
# 0                       pandemic drone spot infected  03/04/2020
# 1                     census data anonymous expected  07/04/2020
# 2  common pandemic scams highlighted domain name ...  11/05/2020
# 3   questions rapidly unfolding future smart fabrics  11/05/2020
# 4                 things ceo expect remote work life  17/05/2020
#
#                                       Trend  Anno  Mese  Day  Week  \
# 0  Robotics and Human/Machine Hybridization  2020     4    3    14
# 1            Privacy and Security by design  2020     4    7    15
# 2     Cyber Defense and Fight against Fakes  2020     5   11    20
# 3                  Workforce Transformation  2020     5   11    20
# 4                  Workforce Transformation  2020     5   17    20
#
#                                             Keywords  \
# 0  drone,detect,respiratory,infected,heart,pandem...
# 1  census,cookies,ad,tracking,adobe,file,party,we...
# 2  scams,fake,information,domain names,sites,doma...
# 3  unfolding,analyze,signs,monitor,vital,question...
# 4  productivity,im,bump,remote,meetings,working,z...
#
#                                   Tags_x  ...   Tag_x  \
# 0                           Tech: Drones  ...
# 1  Company: Adobe, Vertical: Advertising  ...
# 2                                         ...
# 3                            Tag: Future  ...  Future
# 4                                         ...
#
#                                   Tags_y  Tech_y Company_y   Vertical_y  \
# 0                           Tech: Drones  Drones
# 1  Company: Adobe, Vertical: Advertising             Adobe  Advertising
# 2
# 3                            Tag: Future
# 4
#
#   Application_y Location_y   Tag_y  \
# 0
# 1
# 2
# 3                           Future
# 4
#
#                                                Words  \
# 0  [airports, computer vision, drone, heart, inno...
# 1                          [ad, adobe, ads, privacy]
# 2                  [cybersecurity, health, security]
# 3                                           [future]
# 4                                 [working remotely]
#
#                                                 Tags
# 0  [Vertical: Aviation, Application: Computer Vis...
# 1  [Vertical: Advertising, Company: Adobe, Vertic...
# 2                   [Application: Cybersecurity, , ]
# 3                                      [Tag: Future]
# 4                                                 []
#
# [5 rows x 25 columns]

# %%
print ("Numero: %d" % len(df['ID']))
# Out:
# Numero: 439
