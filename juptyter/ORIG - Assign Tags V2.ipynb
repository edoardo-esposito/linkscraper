# %%
import pandas as pd
import numpy as np
import json
import nltk
import re
import csv
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from datetime import datetime
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# %%
meta = pd.read_csv('Articoli Taggati v8.csv', sep=";", skipinitialspace = True, quotechar='"')
#meta = meta.replace(np.nan, '', regex=True)
del(meta['Unnamed: 0'])
del(meta['Txt'])

# %%
meta.head()
# Out:
#                                  ID  \
# 0  7f9f2aea41caf2f034af9b5423abb95f
# 1  c812e0a3418d624ae60df3ec9e19d184
# 2  61268fb46585bba4ac828cc277b69ecb
# 3  d3e4f8a85f1c96d9839de642e856645f
# 4  879f738c66345cf45682fc3e2117e743
#
#                                               Titolo        Data  \
# 0  investor group european oil gas major credible...  2020-05-14
# 1                       pandemic drone spot infected  2020-04-03
# 2  europe green deal eu commission president ursu...  2019-12-15
# 3  green swans exponential decade conversation jo...  2020-05-19
# 4  sustainable nation film showcases israeli wate...  2020-04-26
#
#                                                Trend  Anno  Mese  Day  Week  \
# 0  Circular Economy Sustainability and Zero Impac...  2020     5   14    20
# 1           Robotics and Human/Machine Hybridization  2020     4    3    14
# 2                                  High Tech Farming  2019    12   15    50
# 3             Digital Politics and Smart Citizenship  2020     5   19    21
# 4                              Smart & Digital Water  2020     4   26    17
#
#                                        Keywords          Tags    Tech Company  \
# 0             netzero,oil,tpi,oil gas,emissions           NaN     NaN     NaN
# 1       drone,detect,respiratory,infected,heart  Tech: Drones  Drones     NaN
# 2  europe,von,december th cynthia,man,announces           NaN     NaN     NaN
# 3        elkington,swans,green swans,green,swan           NaN     NaN     NaN
# 4          film,nation,israel,water,sustainable           NaN     NaN     NaN
#
#   Vertical Application Location  Tag
# 0      NaN         NaN      NaN  NaN
# 1      NaN         NaN      NaN  NaN
# 2      NaN         NaN      NaN  NaN
# 3      NaN         NaN      NaN  NaN
# 4      NaN         NaN      NaN  NaN

# %%
print ("Articoli: %d" % len(meta['ID']))
# Out:
# Articoli: 741

# %%
print ("articoli senza tag: %d" % meta['Tags'].isnull().values.sum())
# Out:
# articoli senza tag: 452

# %%
print ("articoli senza keyword: %d" % meta['Keywords'].isnull().values.sum())
# Out:
# articoli senza keyword: 0

# %%
meta['Keywords'][1].split(',')
# Out:
# ['drone', 'detect', 'respiratory', 'infected', 'heart']

# %%
tags = pd.read_excel("Keywords to Tags V2.xlsx", encoding="utf8", error_bad_lines=False)
tags = tags.replace(np.nan, '', regex=True)
del(tags['Tag 1'])
del(tags['Tag 2'])
del(tags['Tag 3'])

# %%
tags.head()
# Out:
#           Words                                           Tags
# 0  aarogya setu  Tech: Mobile app|Application: contact tracing
# 1      academic                           Vertical: University
# 2     acquiring                                  Vertical: M&A
# 3            ad                          Vertical: Advertising
# 4   ad networks                          Vertical: Advertising

# %%
articoli = meta[['ID','Keywords']]

# %%
articoli.head()
# Out:
#                                  ID  \
# 0  7f9f2aea41caf2f034af9b5423abb95f
# 1  c812e0a3418d624ae60df3ec9e19d184
# 2  61268fb46585bba4ac828cc277b69ecb
# 3  d3e4f8a85f1c96d9839de642e856645f
# 4  879f738c66345cf45682fc3e2117e743
#
#                                        Keywords
# 0             netzero,oil,tpi,oil gas,emissions
# 1       drone,detect,respiratory,infected,heart
# 2  europe,von,december th cynthia,man,announces
# 3        elkington,swans,green swans,green,swan
# 4          film,nation,israel,water,sustainable

# %%
len(articoli['ID'])
# Out:
# 741

# %%
words = pd.concat([pd.Series(row['ID'], row['Keywords'].split(',')) 
           for _, row in articoli.iterrows()]).reset_index().rename(columns={"index": "Words", 0: "ID"})

# %%
words.head()
# Out:
#        Words                                ID
# 0    netzero  7f9f2aea41caf2f034af9b5423abb95f
# 1        oil  7f9f2aea41caf2f034af9b5423abb95f
# 2        tpi  7f9f2aea41caf2f034af9b5423abb95f
# 3    oil gas  7f9f2aea41caf2f034af9b5423abb95f
# 4  emissions  7f9f2aea41caf2f034af9b5423abb95f

# %%
res = tags.merge(words, on="Words", how='left')

# %%
res.head()
# Out:
#           Words                                           Tags  \
# 0  aarogya setu  Tech: Mobile app|Application: contact tracing
# 1      academic                           Vertical: University
# 2      academic                           Vertical: University
# 3     acquiring                                  Vertical: M&A
# 4            ad                          Vertical: Advertising
#
#                                  ID
# 0                               NaN
# 1  cf4a502cbc3be4bf184002d5db67ac81
# 2  c3867e2ca29ffade71f104301bf2a743
# 3                               NaN
# 4  0e2ef6bd7619374e0531d1551ab2141e

# %%
#res.to_csv('prova.csv', sep=";")

# %%
res = res.groupby('ID').agg(lambda x: x.tolist()).rename({'Tags': 'ComputedTags'}, axis=1)

# %%
res.head()
# Out:
#                                                      Words  \
# ID
# 005b6d185b27aa2b15483734fac9c657                   [solar]
# 00b4785a7e2de5a5df9b6ee9adba52e7                 [florida]
# 021bf18c94ed25c0ed697b8e73f588cb  [innovation, university]
# 024e39e4c912e043aceb022b442f8a6e          [silicon valley]
# 02783899e72f373f5fa8b56cb84b7d1a     [health, rpa, uipath]
#
#                                          ComputedTags
# ID
# 005b6d185b27aa2b15483734fac9c657                   []
# 00b4785a7e2de5a5df9b6ee9adba52e7  [Location: Florida]
# 021bf18c94ed25c0ed697b8e73f588cb                 [, ]
# 024e39e4c912e043aceb022b442f8a6e                   []
# 02783899e72f373f5fa8b56cb84b7d1a               [, , ]

# %%
df = meta.merge(res, on="ID", how='left')

# %%
df = df.replace(np.nan, '', regex=True)

# %%
df.head()
# Out:
#                                  ID  \
# 0  7f9f2aea41caf2f034af9b5423abb95f
# 1  c812e0a3418d624ae60df3ec9e19d184
# 2  61268fb46585bba4ac828cc277b69ecb
# 3  d3e4f8a85f1c96d9839de642e856645f
# 4  879f738c66345cf45682fc3e2117e743
#
#                                               Titolo        Data  \
# 0  investor group european oil gas major credible...  2020-05-14
# 1                       pandemic drone spot infected  2020-04-03
# 2  europe green deal eu commission president ursu...  2019-12-15
# 3  green swans exponential decade conversation jo...  2020-05-19
# 4  sustainable nation film showcases israeli wate...  2020-04-26
#
#                                                Trend  Anno  Mese  Day  Week  \
# 0  Circular Economy Sustainability and Zero Impac...  2020     5   14    20
# 1           Robotics and Human/Machine Hybridization  2020     4    3    14
# 2                                  High Tech Farming  2019    12   15    50
# 3             Digital Politics and Smart Citizenship  2020     5   19    21
# 4                              Smart & Digital Water  2020     4   26    17
#
#                                        Keywords          Tags    Tech Company  \
# 0             netzero,oil,tpi,oil gas,emissions
# 1       drone,detect,respiratory,infected,heart  Tech: Drones  Drones
# 2  europe,von,december th cynthia,man,announces
# 3        elkington,swans,green swans,green,swan
# 4          film,nation,israel,water,sustainable
#
#   Vertical Application Location Tag                         Words  \
# 0                                                  [oil, oil gas]
# 1                                                  [drone, heart]
# 2                                                        [europe]
# 3
# 4                                    [israel, sustainable, water]
#
#          ComputedTags
# 0                [, ]
# 1    [Tech: Drones, ]
# 2  [Location: Europe]
# 3
# 4              [, , ]

# %%
print ("Numero: %d" % len(df['ID']))
# Out:
# Numero: 741

# %%
def string_to_list(text):
    str_list = text
    str_list = list(filter(None, str_list))
    str_list = list(set(str_list))
    
    str_list = ", " . join(str_list)
    
    return str_list
    
string_to_list(df['ComputedTags'][736])
# Out:
# ''

# %%
df['ComputedTags'] = df['ComputedTags'].apply(lambda x: string_to_list(x))

# %%
df.head()
# Out:
#                                  ID  \
# 0  7f9f2aea41caf2f034af9b5423abb95f
# 1  c812e0a3418d624ae60df3ec9e19d184
# 2  61268fb46585bba4ac828cc277b69ecb
# 3  d3e4f8a85f1c96d9839de642e856645f
# 4  879f738c66345cf45682fc3e2117e743
#
#                                               Titolo        Data  \
# 0  investor group european oil gas major credible...  2020-05-14
# 1                       pandemic drone spot infected  2020-04-03
# 2  europe green deal eu commission president ursu...  2019-12-15
# 3  green swans exponential decade conversation jo...  2020-05-19
# 4  sustainable nation film showcases israeli wate...  2020-04-26
#
#                                                Trend  Anno  Mese  Day  Week  \
# 0  Circular Economy Sustainability and Zero Impac...  2020     5   14    20
# 1           Robotics and Human/Machine Hybridization  2020     4    3    14
# 2                                  High Tech Farming  2019    12   15    50
# 3             Digital Politics and Smart Citizenship  2020     5   19    21
# 4                              Smart & Digital Water  2020     4   26    17
#
#                                        Keywords          Tags    Tech Company  \
# 0             netzero,oil,tpi,oil gas,emissions
# 1       drone,detect,respiratory,infected,heart  Tech: Drones  Drones
# 2  europe,von,december th cynthia,man,announces
# 3        elkington,swans,green swans,green,swan
# 4          film,nation,israel,water,sustainable
#
#   Vertical Application Location Tag                         Words  \
# 0                                                  [oil, oil gas]
# 1                                                  [drone, heart]
# 2                                                        [europe]
# 3
# 4                                    [israel, sustainable, water]
#
#        ComputedTags
# 0
# 1      Tech: Drones
# 2  Location: Europe
# 3
# 4

# %%
df.to_csv('prova.csv', sep=";")
